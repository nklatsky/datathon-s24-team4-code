# %% [markdown]
# # EDA
#
# Perform exploratory data analysis and visualization for:
#
# <br>
#
# *American Community Survey - Selected Economic Characteristics (5 Year Estimates)*
#
# **acs_5yr_est_selected_economic_characteristics_2010-2022.csv**
#
# The American Community Survey (ACS) is an ongoing survey conducted by the US Census
# Bureau that provides vital information on a yearly basis about various social and economic
# characteristics across demographics.
# ~98K rows & 8 columns. Size: 12.1 MB. Source: American Community Survey
#
# <br>
#
# *Energy Sector Stocks and Commodities (HLOC)*
#
# **all_commodities.csv**
#
# **all_stocks_and_etfs.csv**
#
# **stock_descriptions.csv**
#
#
# A collection of daily high/low/open/close prices for stocks in the energy sector and four
# exchange-traded funds (ETF) that track major indices (S&P 500, Nasdaq, Dow Jones Industrial
# Average), some general information about these companies, and daily prices for energy
# commodities.
# Stocks and ETFs ~145K rows & 7 columns. Size: 7.1 MB
# Commodities ~27K rows & 5 columns. Size: 1.9 MB
# Descriptions 29 rows & 6 columns. Size: 14 KB
# Source: Alpha Vantage and Yahoo! Finance
#
# <br>
#
# *Recent and Historic Energy Statistics*
#
# **Energy Data - Consumption.csv**
#
# **Energy Data - Emissions.csv**
#
# **Energy Data - Imports & Exports.csv**
#
# **Energy Data - Production.csv**
#
# **Energy Data - Stocks.csv**
#
#
# Import/exports volume, production, stocks, consumption, and emissions from energy sources in
# the United States.
# Imports & Exports ~19.5K rows & 10 columns. Size: 2.3 MB
# Production ~10.3K rows & 7 columns. Size: 826 KB
# Stocks ~17.5K rows & 11 columns. Size: 2.3 MB
# Consumption ~57.6K rows & 12 columns. Size: 8.7 MB
# Emissions ~48.3K rows & 10 columns. Size: 7.3 MB
# Source: U.S. Energy Information Administration
#
# <br>
#
# *Monthly Transportation Statistics*
#
# **monthly_transportation_statistics.csv**
#
#
# The latest monthly and quarterly data from across the government and the transportation
# industry.
# 289 rows & 137 columns. Size: 309 KB. Source: U.S. Dept of Transportation - Bureau of
# Transportation Statistics

# %%
# import libraries for eda
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import os
import sys

data_folderpath = r"data\!Spring_Invitational_2024_data\Datathon_Data"

# %% [markdown]
# ## American Community Survey - Selected Economic Characteristics (5 Year Estimates)
#
# ** **acs_5yr_est_selected_economic_characteristics_2010-2022.csv**

# %%
def str_to_numeric(s):
    if not isinstance(s, str):
        return s
    s_clean = s.replace("%", "").replace(",", "").replace("±", "")
    if s_clean.isnumeric():
        return float(s_clean)
    return s_clean

# %%
def preprocess_econ_data(data):
    for col in ["Percent", "Percent Margin of Error"]:
        data[col] = data[col].apply(str_to_numeric)
    return data.sort_values("Year")

# %%
# import data
econ_data_path = data_folderpath + r"\acs_5yr_est_selected_economic_characteristics_2010-2022.csv"

print(econ_data_path)

econ_data = pd.read_csv(econ_data_path)
econ_data = preprocess_econ_data(econ_data)

#Print type of each col
print(econ_data.dtypes)

for col in econ_data.columns:
    print(col," - " ,type(econ_data[col][0]))

econ_data.head()
# Out:
# data\!Spring_Invitational_2024_data\Datathon_Data\acs_5yr_est_selected_economic_characteristics_2010-2022.csv
# Label (Grouping)           object
# Category                   object
# State                      object
# Estimate                   object
# Margin of Error            object
# Percent                    object
# Percent Margin of Error    object
# Year                        int64
# dtype: object
# Label (Grouping)  -  <class 'str'>
# Category  -  <class 'str'>
# State  -  <class 'str'>
# Estimate  -  <class 'float'>
# Margin of Error  -  <class 'float'>
# Percent  -  <class 'float'>
# Percent Margin of Error  -  <class 'float'>
# Year  -  <class 'numpy.int64'>
#                                   Label (Grouping)                   Category  \
# 0                                EMPLOYMENT STATUS                     Header
# 5034                          With public coverage  HEALTH INSURANCE COVERAGE
# 5033                 With private health insurance  HEALTH INSURANCE COVERAGE
# 5032                With health insurance coverage  HEALTH INSURANCE COVERAGE
# 5031      Civilian noninstitutionalized population  HEALTH INSURANCE COVERAGE
#
#              State Estimate Margin of Error Percent Percent Margin of Error  \
# 0          Alabama      NaN             NaN     NaN                     NaN
# 5034  North Dakota      (X)             (X)     (X)                     (X)
# 5033  North Dakota      (X)             (X)     (X)                     (X)
# 5032  North Dakota      (X)             (X)     (X)                     (X)
# 5031  North Dakota      (X)             (X)     (X)                     (X)
#
#       Year
# 0     2010
# 5034  2010
# 5033  2010
# 5032  2010
# 5031  2010

# %%
top_oil_producers = ["Texas", "New Mexico", "Oklahoma", "Colorado", "North Dakota", "Alaska"] # https://www.investopedia.com/financial-edge/0511/top-6-oil-producing-states.aspx
natural_res_occupation = '\xa0\xa0\xa0\xa0Natural resources, construction, and maintenance occupations'

natural_res = econ_data[(econ_data["Label (Grouping)"] == natural_res_occupation)]

# %%
for state in top_oil_producers:
    plt.plot(natural_res[natural_res["State"] == state]["Year"], natural_res[natural_res["State"] == state]["Percent"].astype(float), label=state)

plt.legend()
plt.show()

# %%
econ_data["Label (Grouping)"].unique()
# Out:
# array(['EMPLOYMENT STATUS', 'Population 16 years and over',
#        '\xa0\xa0\xa0\xa0In labor force',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Civilian labor force',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Employed',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployed',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Armed Forces',
#        '\xa0\xa0\xa0\xa0Not in labor force',
#        '\xa0\xa0\xa0\xa0Civilian labor force',
#        '\xa0\xa0\xa0\xa0Percent Unemployed', 'Females 16 years and over',
#        'Own children under 6 years',
#        '\xa0\xa0\xa0\xa0All parents in family in labor force',
#        'Own children 6 to 17 years', 'COMMUTING TO WORK',
#        'Workers 16 years and over',
#        '\xa0\xa0\xa0\xa0Car, truck, or van -- drove alone',
#        '\xa0\xa0\xa0\xa0Car, truck, or van -- carpooled',
#        '\xa0\xa0\xa0\xa0Public transportation (excluding taxicab)',
#        '\xa0\xa0\xa0\xa0Walked', '\xa0\xa0\xa0\xa0Other means',
#        '\xa0\xa0\xa0\xa0Worked at home',
#        '\xa0\xa0\xa0\xa0Mean travel time to work (minutes)', 'OCCUPATION',
#        'Civilian employed population 16 years and over',
#        '\xa0\xa0\xa0\xa0Management, business, science, and arts occupations',
#        '\xa0\xa0\xa0\xa0Service occupations',
#        '\xa0\xa0\xa0\xa0Sales and office occupations',
#        '\xa0\xa0\xa0\xa0Natural resources, construction, and maintenance occupations',
#        '\xa0\xa0\xa0\xa0Production, transportation, and material moving occupations',
#        'INDUSTRY',
#        '\xa0\xa0\xa0\xa0Agriculture, forestry, fishing and hunting, and mining',
#        '\xa0\xa0\xa0\xa0Construction', '\xa0\xa0\xa0\xa0Manufacturing',
#        '\xa0\xa0\xa0\xa0Wholesale trade', '\xa0\xa0\xa0\xa0Retail trade',
#        '\xa0\xa0\xa0\xa0Transportation and warehousing, and utilities',
#        '\xa0\xa0\xa0\xa0Information',
#        '\xa0\xa0\xa0\xa0Finance and insurance, and real estate and rental and leasing',
#        '\xa0\xa0\xa0\xa0Professional, scientific, and management, and administrative and waste management services',
#        '\xa0\xa0\xa0\xa0Educational services, and health care and social assistance',
#        '\xa0\xa0\xa0\xa0Arts, entertainment, and recreation, and accommodation and food services',
#        '\xa0\xa0\xa0\xa0Other services, except public administration',
#        '\xa0\xa0\xa0\xa0Public administration', 'CLASS OF WORKER',
#        '\xa0\xa0\xa0\xa0Private wage and salary workers',
#        '\xa0\xa0\xa0\xa0Government workers',
#        '\xa0\xa0\xa0\xa0Self-employed in own not incorporated business workers',
#        '\xa0\xa0\xa0\xa0Unpaid family workers',
#        'INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)',
#        '\xa0\xa0\xa0\xa0Total households', 'Less than $10,000',
#        '$10,000 to $14,999', '$15,000 to $24,999', '$25,000 to $34,999',
#        '$35,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999',
#        '$100,000 to $149,999', '$150,000 to $199,999', '$200,000 or more',
#        '\xa0\xa0\xa0\xa0Median household income (dollars)',
#        '\xa0\xa0\xa0\xa0Mean household income (dollars)',
#        '\xa0\xa0\xa0\xa0With earnings',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean earnings (dollars)',
#        '\xa0\xa0\xa0\xa0With Social Security',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean Social Security income (dollars)',
#        '\xa0\xa0\xa0\xa0With retirement income',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean retirement income (dollars)',
#        '\xa0\xa0\xa0\xa0With Supplemental Security Income',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean Supplemental Security Income (dollars)',
#        '\xa0\xa0\xa0\xa0With cash public assistance income',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean cash public assistance income (dollars)',
#        'With Food Stamp/SNAP benefits in the past 12 months',
#        '\xa0\xa0\xa0\xa0Families',
#        '\xa0\xa0\xa0\xa0Median family income (dollars)',
#        '\xa0\xa0\xa0\xa0Mean family income (dollars)',
#        '\xa0\xa0\xa0\xa0Per capita income (dollars)',
#        '\xa0\xa0\xa0\xa0Nonfamily households',
#        '\xa0\xa0\xa0\xa0Median nonfamily income (dollars)',
#        '\xa0\xa0\xa0\xa0Mean nonfamily income (dollars)',
#        '\xa0\xa0\xa0\xa0Median earnings for workers (dollars)',
#        '\xa0\xa0\xa0\xa0Median earnings for male full-time, year-round workers (dollars)',
#        '\xa0\xa0\xa0\xa0Median earnings for female full-time, year-round workers (dollars)',
#        'HEALTH INSURANCE COVERAGE',
#        '\xa0\xa0\xa0\xa0Civilian noninstitutionalized population',
#        '\xa0\xa0\xa0\xa0With health insurance coverage',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage',
#        '\xa0\xa0\xa0\xa0No health insurance coverage',
#        'Civilian noninstitutionalized population under 18 years',
#        'Civilian noninstitutionalized population 18 to 64 years',
#        '\xa0\xa0\xa0\xa0In labor force:',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Employed:',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployed:',
#        '\xa0\xa0\xa0\xa0Not in labor force:',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage',
#        'PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL',
#        '\xa0\xa0\xa0\xa0All families',
#        'With related children under 18 years',
#        'With related children under 5 years only',
#        '\xa0\xa0\xa0\xa0Married couple families',
#        '\xa0\xa0\xa0\xa0Families with female householder, no husband present',
#        '\xa0\xa0\xa0\xa0All people', 'Under 18 years',
#        'Related children under 18 years',
#        'Related children under 5 years', 'Related children 5 to 17 years',
#        '18 years and over', '18 to 64 years', '65 years and over',
#        '\xa0\xa0\xa0\xa0People in families',
#        'Unrelated individuals 15 years and over',
#        'INCOME AND BENEFITS (IN 2011 INFLATION-ADJUSTED DOLLARS)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0In labor force',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Civilian labor force',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Employed',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployed',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Armed Forces',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Not in labor force',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Percent Unemployed',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0All parents in family in labor force',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Car, truck, or van -- drove alone',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Car, truck, or van -- carpooled',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Public transportation (excluding taxicab)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Walked',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Other means',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Worked at home',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Management, business, science, and arts occupations',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Service occupations',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Sales and office occupations',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Natural resources, construction, and maintenance occupations',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Production, transportation, and material moving occupations',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Agriculture, forestry, fishing and hunting, and mining',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Construction',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Manufacturing',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Wholesale trade',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Retail trade',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Transportation and warehousing, and utilities',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Information',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Finance and insurance, and real estate and rental and leasing',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Professional, scientific, and management, and administrative and waste management services',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Educational services, and health care and social assistance',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Arts, entertainment, and recreation, and accommodation and food services',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Other services, except public administration',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Public administration',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Private wage and salary workers',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Government workers',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Self-employed in own not incorporated business workers',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unpaid family workers',
#        'INCOME AND BENEFITS (IN 2013 INFLATION-ADJUSTED DOLLARS)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Median household income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean household income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Median family income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean family income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Median nonfamily income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean nonfamily income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0In labor force:',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Employed:',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployed:',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Not in labor force:',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0People in families',
#        'INCOME AND BENEFITS (IN 2012 INFLATION-ADJUSTED DOLLARS)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployment Rate',
#        'Own children of the householder under 6 years',
#        'Own children of the householder 6 to 17 years',
#        'INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS)',
#        'With related children of the householder under 18 years',
#        'With related children of the householder under 5 years only',
#        'Related children of the householder under 18 years',
#        'Related children of the householder under 5 years',
#        'Related children of the householder 5 to 17 years',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean travel time to work (minutes)',
#        'INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With earnings',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean earnings (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With Social Security',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean Social Security income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With retirement income',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean retirement income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With Supplemental Security Income',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean Supplemental Security Income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With cash public assistance income',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean cash public assistance income (dollars)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Per capita income (dollars)',
#        'Civilian noninstitutionalized population under 19 years',
#        'Civilian noninstitutionalized population 19 to 64 years',
#        'INCOME AND BENEFITS (IN 2015 INFLATION-ADJUSTED DOLLARS)',
#        'INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Worked from home',
#        'INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Married couple families',
#        '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Families with female householder, no spouse present',
#        'INCOME AND BENEFITS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#        'INCOME AND BENEFITS (IN 2022 INFLATION-ADJUSTED DOLLARS)',
#        'INCOME AND BENEFITS (IN 2020 INFLATION-ADJUSTED DOLLARS)',
#        'INCOME AND BENEFITS (IN 2021 INFLATION-ADJUSTED DOLLARS)'],
#       dtype=object)

# %% [markdown]
# ## Energy Sector Stocks and Commodities (HLOC)

# %% [markdown]
# ### **all_commodities.csv**

# %%
# import data

commodities_data_path = data_folderpath + r"/all_commodities.csv"

print(commodities_data_path)

commodities_data = pd.read_csv(commodities_data_path).sort_values("Date_Time")
# Out:
# data\!Spring_Invitational_2024_data\Datathon_Data/all_commodities.csv

# %%
natural_gas = commodities_data[commodities_data["Commodity_Simple"] == "NATURAL_GAS"]

plt.gca().xaxis.set_major_locator(mdates.YearLocator())

plt.plot(natural_gas["Date_Time"], natural_gas["Value"])
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ### **all_stocks_and_etfs.csv**

# %%
# import data
stocks_path = data_folderpath + r"/all_stocks_and_etfs.csv"

print(stocks_path)

stocks = pd.read_csv(stocks_path).sort_values("Date-Time")
# Out:
# data\!Spring_Invitational_2024_data\Datathon_Data/all_stocks_and_etfs.csv

# %%
stocks.head()
# Out:
#          Date-Time     Open     High       Low     Close   Volume  \
# 144557  1999-11-01  136.500  137.000  135.5625  135.5625  4006500
# 34973   1999-11-01    8.813    8.875    8.7500    8.7500    20700
# 106080  1999-11-01   20.750   21.060   20.5600   21.0000   209000
# 117765  1999-11-01   61.250   62.560   59.7500   62.5000  2854800
# 6096    1999-11-01   38.250   38.810   36.7500   38.7500  3166300
#
#        Ticker_Symbol
# 144557           SPY
# 34973            BPT
# 106080           EOG
# 117765           SLB
# 6096             HAL

# %%
stocks["Ticker_Symbol"].unique()
# Out:
# array(['SPY', 'BPT', 'EOG', 'SLB', 'HAL', 'VLO', 'XOM', 'EXC', 'CVX',
#        'BP', 'HES', 'OXY', 'EPD', 'E', 'COP', 'NOV', 'DVN', 'DIA', 'WMB',
#        'CEO', 'ONEQ', 'VOO', 'KMI', 'MPC', 'PSX', 'FANG', 'BKR', 'CHK'],
#       dtype=object)

# %% [markdown]
# ### **stock_descriptions.csv**

# %%
# import data

stock_descriptions_path = data_folderpath + r"\stock_descriptions.csv"
stock_descriptions = pd.read_csv(stock_descriptions_path)

stock_descriptions.head()
# Out:
#   Symbol     AssetType                           Name  \
# 0    BKR  Common Stock           Baker Hughes Company
# 1     BP  Common Stock                     BP PLC ADR
# 2    BPT  Common Stock   BP Prudhoe Bay Royalty Trust
# 3    CEO  Common Stock                  CNOOC Limited
# 4    CHK  Common Stock  Chesapeake Energy Corporation
#
#                                          Description                   Sector  \
# 0  Baker Hughes Company provides a portfolio of t...  ENERGY & TRANSPORTATION
# 1  BP plc participates in the energy business glo...  ENERGY & TRANSPORTATION
# 2  BP Prudhoe Bay Royalty Trust is a grantor trus...               TECHNOLOGY
# 3  CNOOC Limited operates exploration and product...  ENERGY & TRANSPORTATION
# 4  Chesapeake Energy Corporation, an independent ...  ENERGY & TRANSPORTATION
#
#                          Industry
# 0  OIL & GAS EQUIPMENT & SERVICES
# 1              PETROLEUM REFINING
# 2                         GENERAL
# 3  OIL & GAS EQUIPMENT & SERVICES
# 4  OIL & GAS EQUIPMENT & SERVICES

# %%
stock_descriptions
# Out:
#    Symbol     AssetType                                         Name  \
# 0     BKR  Common Stock                         Baker Hughes Company
# 1      BP  Common Stock                                   BP PLC ADR
# 2     BPT  Common Stock                 BP Prudhoe Bay Royalty Trust
# 3     CEO  Common Stock                                CNOOC Limited
# 4     CHK  Common Stock                Chesapeake Energy Corporation
# 5     COP  Common Stock                               ConocoPhillips
# 6     CVX  Common Stock                                 Chevron Corp
# 7     DVN  Common Stock                     Devon Energy Corporation
# 8       E  Common Stock                                    Eni S.p.A
# 9     EOG  Common Stock                            EOG Resources Inc
# 10    EPD  Common Stock            Enterprise Products Partners L.P.
# 11    EXC  Common Stock                           Exelon Corporation
# 12   FANG  Common Stock                     Diamondback Energy, Inc.
# 13    HAL  Common Stock                          Halliburton Company
# 14    HES  Common Stock                             Hess Corporation
# 15    KMI  Common Stock                            Kinder Morgan Inc
# 16    MPC  Common Stock         Marathon Petroleum Corporation (MPC)
# 17    NOV  Common Stock                                     NOV Inc.
# 18    OXY  Common Stock             Occidental Petroleum Corporation
# 19    PSX  Common Stock                                  Phillips 66
# 20    SLB  Common Stock                              Schlumberger NV
# 21    VLO  Common Stock                    Valero Energy Corporation
# 22    WMB  Common Stock                       Williams Companies Inc
# 23    XOM  Common Stock                             Exxon Mobil Corp
# 24    DIA           ETF  SPDR Dow Jones Industrial Average ETF Trust
# 25   ONEQ           ETF          Fidelity Nasdaq Composite Index ETF
# 26    SPY           ETF                 SPDR S&P 500 ETF Trust (SPY)
# 27    VOO           ETF                Vanguard 500 Index Fund (VOO)
#
#                                           Description  \
# 0   Baker Hughes Company provides a portfolio of t...
# 1   BP plc participates in the energy business glo...
# 2   BP Prudhoe Bay Royalty Trust is a grantor trus...
# 3   CNOOC Limited operates exploration and product...
# 4   Chesapeake Energy Corporation, an independent ...
# 5   ConocoPhillips is an American multinational co...
# 6   Chevron Corporation is an American multination...
# 7   Devon Energy Corporation is an American energy...
# 8   Eni S.p.A. operates as an integrated energy co...
# 9   EOG Resources, Inc. is an American energy comp...
# 10  Enterprise Products Partners L.P. provides mid...
# 11  Exelon Corporation is an American Fortune 100 ...
# 12  Diamondback Energy, Inc., an independent oil a...
# 13  Halliburton Company is an American multination...
# 14  Hess Corporation (formerly Amerada Hess Corpor...
# 15  Kinder Morgan, Inc. is one of the largest ener...
# 16  Marathon Petroleum Corporation, together with ...
# 17  NOV Inc. is an American multinational corporat...
# 18  Occidental Petroleum Corporation is an America...
# 19  The Phillips 66 Company is an American multina...
# 20  Schlumberger Limited is an oilfield services c...
# 21  Valero Energy Corporation is a Fortune 500 int...
# 22  The Williams Companies, Inc., is an American e...
# 23  Exxon Mobil Corporation, stylized as ExxonMobi...
# 24  The DIA stock price tracks the performance of ...
# 25  The ONEQ stock price tracks the performance of...
# 26  The SPY stock price tracks the performance of ...
# 27  The VOO stock price tracks the performance of ...
#
#                      Sector                               Industry
# 0   ENERGY & TRANSPORTATION         OIL & GAS EQUIPMENT & SERVICES
# 1   ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 2                TECHNOLOGY                                GENERAL
# 3   ENERGY & TRANSPORTATION         OIL & GAS EQUIPMENT & SERVICES
# 4   ENERGY & TRANSPORTATION         OIL & GAS EQUIPMENT & SERVICES
# 5   ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 6   ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 7   ENERGY & TRANSPORTATION          CRUDE PETROLEUM & NATURAL GAS
# 8   ENERGY & TRANSPORTATION                   OIL & GAS INTEGRATED
# 9   ENERGY & TRANSPORTATION          CRUDE PETROLEUM & NATURAL GAS
# 10  ENERGY & TRANSPORTATION                    OIL & GAS MIDSTREAM
# 11  ENERGY & TRANSPORTATION     ELECTRIC & OTHER SERVICES COMBINED
# 12  ENERGY & TRANSPORTATION                          OIL & GAS E&P
# 13  ENERGY & TRANSPORTATION          OIL & GAS FIELD SERVICES, NEC
# 14  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 15  ENERGY & TRANSPORTATION               NATURAL GAS TRANSMISSION
# 16  ENERGY & TRANSPORTATION         OIL & GAS REFINING & MARKETING
# 17               TECHNOLOGY  OIL & GAS FIELD MACHINERY & EQUIPMENT
# 18  ENERGY & TRANSPORTATION          CRUDE PETROLEUM & NATURAL GAS
# 19  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 20  ENERGY & TRANSPORTATION          OIL & GAS FIELD SERVICES, NEC
# 21  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 22  ENERGY & TRANSPORTATION               NATURAL GAS TRANSMISSION
# 23  ENERGY & TRANSPORTATION                     PETROLEUM REFINING
# 24                 MULTIPLE                               MULTIPLE
# 25                 MULTIPLE                               MULTIPLE
# 26                 MULTIPLE                               MULTIPLE
# 27                 MULTIPLE                               MULTIPLE

# %% [markdown]
# ## Recent and Historic Energy Statistics

# %% [markdown]
# ### **Energy Data - Consumption.csv**

# %%
# import data

energy_consumption_path = data_folderpath + r"\Energy Data - Consumption.csv"
energy_consumption = pd.read_csv(energy_consumption_path)

energy_consumption.head()
# Out:
#     EIA_ID  YYYYMM      Date     Value  Column_Order  \
# 0  DFRCPUS  197301  1/1/1973  1706.943             1
# 1  DFRCPUS  197302  2/1/1973  1614.436             1
# 2  DFRCPUS  197303  3/1/1973  1140.521             1
# 3  DFRCPUS  197304  4/1/1973   824.604             1
# 4  DFRCPUS  197305  5/1/1973   676.745             1
#
#                                          Description  \
# 0  Distillate Fuel Oil Consumed by the Residentia...
# 1  Distillate Fuel Oil Consumed by the Residentia...
# 2  Distillate Fuel Oil Consumed by the Residentia...
# 3  Distillate Fuel Oil Consumed by the Residentia...
# 4  Distillate Fuel Oil Consumed by the Residentia...
#
#                        Unit          Energy Type      Energy Category  \
# 0  Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
# 1  Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
# 2  Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
# 3  Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
# 4  Thousand Barrels per Day  Distillate Fuel Oil  Distillate Fuel Oil
#
#   Energy Class       Sector
# 0    Petroleum  Residential
# 1    Petroleum  Residential
# 2    Petroleum  Residential
# 3    Petroleum  Residential
# 4    Petroleum  Residential

# %%
energy_consumption["Description"].unique()
# Out:
# array(['Distillate Fuel Oil Consumed by the Residential Sector',
#        'Propane Consumed by the Residential Sector',
#        'Kerosene Consumed by the Residential Sector',
#        'Total Petroleum Consumed by the Residential Sector',
#        'Distillate Fuel Oil Consumed by the Commercial Sector',
#        'Propane Consumed by the Commercial Sector',
#        'Kerosene Consumed by the Commercial Sector',
#        'Motor Gasoline Consumed by the Commercial Sector',
#        'Petroleum Coke Consumed by the Commercial Sector',
#        'Residual Fuel Oil Consumed by the Commercial Sector',
#        'Total Petroleum Consumed by the Commercial Sector',
#        'Asphalt and Road Oil Consumed by the Industrial Sector',
#        'Distillate Fuel Oil Consumed by the Industrial Sector',
#        'Propane Consumed by the Industrial Sector',
#        'Propylene Consumed by the Industrial Sector',
#        'Propane/Propylene Consumed by the Industrial Sector',
#        'Total Hydrocarbon Gas Liquids Consumed by the Industrial Sector',
#        'Kerosene Consumed by the Industrial Sector',
#        'Lubricants Consumed by the Industrial Sector',
#        'Motor Gasoline Consumed by the Industrial Sector',
#        'Petroleum Coke Consumed by the Industrial Sector',
#        'Residual Fuel Oil Consumed by the Industrial Sector',
#        'Other Petroleum Products Consumed by the Industrial Sector',
#        'Total Petroleum Consumed by the Industrial Sector',
#        'Aviation Gasoline Consumed by the Transportation Sector',
#        'Distillate Fuel Oil Consumed by the Transportation Sector',
#        'Propane Consumed by the Transportation Sector',
#        'Jet Fuel Consumed by the Transportation Sector',
#        'Lubricants Consumed by the Transportation Sector',
#        'Motor Gasoline Consumed by the Transportation Sector',
#        'Residual Fuel Oil Consumed by the Transportation Sector',
#        'Other Products Consumed by the Transportation Sector',
#        'Total Petroleum Consumed by the Transportation Sector',
#        'Distillate Fuel Oil Consumed by the Electric Power Sector',
#        'Petroleum Coke Consumed by the Electric Power Sector',
#        'Residual Fuel Oil Consumed by the Electric Power Sector',
#        'Total Petroleum Consumed by the Electric Power Sector',
#        'Geothermal Energy Consumed by the Residential Sector',
#        'Solar Energy Consumed by the Residential Sector',
#        'Wood Energy Consumed by the Residential Sector',
#        'Total Renewable Energy Consumed by the Residential Sector',
#        'Hydroelectric Power Consumed by the Commercial Sector',
#        'Geothermal Energy Consumed by the Commercial Sector',
#        'Solar Energy Consumed by the Commercial Sector',
#        'Wind Energy Consumed by the Commercial Sector',
#        'Wood Energy Consumed by the Commercial Sector',
#        'Waste Energy Consumed by the Commercial Sector',
#        'Fuel Ethanol, Excluding Denaturant, Consumed by the Commercial Sector',
#        'Biomass Energy Consumed by the Commercial Sector',
#        'Total Renewable Energy Consumed by the Commercial Sector',
#        'Hydroelectric Power Consumed by the Industrial Sector',
#        'Geothermal Energy Consumed by the Industrial Sector',
#        'Solar Energy Consumed by the Industrial Sector',
#        'Wind Energy Consumed by the Industrial Sector',
#        'Wood Energy Consumed by the Industrial Sector',
#        'Waste Energy Consumed by the Industrial Sector',
#        'Fuel Ethanol, Excluding Denaturant, Consumed by the Industrial Sector',
#        'Biomass Losses and Co-products in the Industrial Sector',
#        'Biomass Energy Consumed by the Industrial Sector',
#        'Total Renewable Energy Consumed by the Industrial Sector',
#        'Hydroelectric Power Consumption', 'Geothermal Energy Consumption',
#        'Solar Energy Consumption', 'Wind Energy Consumption',
#        'Wood Energy Consumption', 'Waste Energy Consumption',
#        'Biofuels Consumption', 'Total Biomass Energy Consumption',
#        'Total Renewable Energy Consumption',
#        'Natural Gas Consumed by the Residential Sector',
#        'Natural Gas Consumed by the Commercial Sector',
#        'Natural Gas Consumed by the Industrial Sector, Lease and Plant Fuel',
#        'Natural Gas Consumed by the Other Industrial Sector, CHP',
#        'Natural Gas Consumed by the Other Industrial Sector, Non-CHP',
#        'Natural Gas Consumed by the Other Industrial Sector, Total',
#        'Natural Gas Consumed by the Industrial Sector, Total',
#        'Natural Gas Consumed by the Transportation Sector, Pipelines and Distribution',
#        'Natural Gas Consumed by the Transportation Sector, Vehicle Fuel',
#        'Natural Gas Consumed by the Transportation Sector, Total',
#        'Natural Gas Consumed by the Electric Power Sector',
#        'Natural Gas Consumption, Total',
#        'Coal Consumed by the Residential Sector',
#        'Coal Consumed by the Commercial Sector, CHP',
#        'Coal Consumed by the Commercial Sector, Other',
#        'Coal Consumed by the Commercial Sector, Total',
#        'Coal Consumed by the Industrial Sector, Coke Plants',
#        'Coal Consumed by the Other Industrial Sector, CHP',
#        'Coal Consumed by the Other Industrial Sector, Non-CHP',
#        'Coal Consumed by the Other Industrial Sector, Total',
#        'Coal Consumed by the Industrial Sector, Total',
#        'Coal Consumed by the Transportation Sector',
#        'Coal Consumed by the Electric Power Sector',
#        'Coal Consumption, Total'], dtype=object)

# %% [markdown]
# ### **Energy Data - Emissions.csv**

# %%
# import data

energy_emissions_path = data_folderpath + r"\Energy Data - Emissions.csv"
energy_emissions = pd.read_csv(energy_emissions_path)

energy_emissions = energy_emissions[energy_emissions["Value"] != "Not Available"]

energy_emissions.head()
# Out:
#        MSN  YYYYMM      Date    Value  Column_Order  \
# 0  CKTCEUS  197301  1/1/1973  109.552             1
# 1  CKTCEUS  197302  2/1/1973   98.833             1
# 2  CKTCEUS  197303  3/1/1973   98.483             1
# 3  CKTCEUS  197304  4/1/1973    94.15             1
# 4  CKTCEUS  197305  5/1/1973   95.424             1
#
#                                          Description  \
# 0  Coal, Including Coal Coke Net Imports, CO2 Emi...
# 1  Coal, Including Coal Coke Net Imports, CO2 Emi...
# 2  Coal, Including Coal Coke Net Imports, CO2 Emi...
# 3  Coal, Including Coal Coke Net Imports, CO2 Emi...
# 4  Coal, Including Coal Coke Net Imports, CO2 Emi...
#
#                                     Unit Energy Type Energy Class Sector
# 0  Million Metric Tons of Carbon Dioxide        Coal         Coal    NaN
# 1  Million Metric Tons of Carbon Dioxide        Coal         Coal    NaN
# 2  Million Metric Tons of Carbon Dioxide        Coal         Coal    NaN
# 3  Million Metric Tons of Carbon Dioxide        Coal         Coal    NaN
# 4  Million Metric Tons of Carbon Dioxide        Coal         Coal    NaN

# %%
energy_emissions["Energy Type"].unique(), energy_emissions["Energy Class"].unique()
# Out:
# (array(['Coal', 'Natural Gas', 'Aviation Gasoline', 'Distillate Fuel Oil',
#         'Hydrocarbon Gas Liquids (HGL)', 'Jet Fuel', 'Kerosene',
#         'Lubricants', 'Motor Gasoline', 'Petroleum Coke',
#         'Residual Fuel Oil', 'Other', 'Total', 'Electricity', 'Coal Coke',
#         'Geothermal Energy', 'Non-Biomass Waste', 'Wood', 'Biomass Waste',
#         'Fuel Ethanol', 'Biodiesel', 'Biomass'], dtype=object),
#  array(['Coal', 'Natural Gas', 'Petroleum', 'Total', 'Electricity',
#         'Geothermal Energy', 'Non-Biomass Waste', 'Biomass'], dtype=object))

# %%
energy_emissions["Value"] = energy_emissions["Value"].apply(lambda s: int(s.replace(".", "")))

agg_emissions = (
    energy_emissions[energy_emissions["Value"] != "Not Available"]
    .groupby(["YYYYMM", "Energy Class", "Unit", "Sector"])
    .agg("sum").reset_index()
    [["YYYYMM", "Energy Class", "Unit", "Sector", "Value"]]
)
# Out:
# C:\Users\nicho\AppData\Local\Temp\ipykernel_7196\4122644063.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .agg("sum").reset_index()

# %%
agg_emissions[agg_emissions["Energy Class"] == "Total"]["Sector"].unique()
# Out:
# array(['Commercial', 'Electric Power', 'Industrial', 'Residential',
#        'Transportation'], dtype=object)

# %% [markdown]
# ### **Energy Data - Imports & Exports.csv**

# %%
# import data
imports_exports_path = data_folderpath + r"/Energy Data - Imports & Exports.csv"

imports_export = pd.read_csv(imports_exports_path)

imports_export.head()
# Out:
#     EIA_ID  YYYYMM      Date    Value  Column_Order  \
# 0  PAIMPAG  197301  1/1/1973  180.065             1
# 1  PAIMPAG  197302  2/1/1973  173.679             1
# 2  PAIMPAG  197303  3/1/1973  141.323             1
# 3  PAIMPAG  197304  4/1/1973  108.867             1
# 4  PAIMPAG  197305  5/1/1973  180.581             1
#
#                       Description  Country                      Unit  OPEC  \
# 0  Petroleum Imports From Algeria  Algeria  Thousand Barrels per Day  True
# 1  Petroleum Imports From Algeria  Algeria  Thousand Barrels per Day  True
# 2  Petroleum Imports From Algeria  Algeria  Thousand Barrels per Day  True
# 3  Petroleum Imports From Algeria  Algeria  Thousand Barrels per Day  True
# 4  Petroleum Imports From Algeria  Algeria  Thousand Barrels per Day  True
#
#   Import Export
# 0        Import
# 1        Import
# 2        Import
# 3        Import
# 4        Import

# %% [markdown]
# ### **Energy Data - Production.csv**

# %%
# import data

energy_production_path = data_folderpath + r"\Energy Data - Production.csv"
energy_production = pd.read_csv(energy_production_path)

energy_production.head()
# Out:
#     EIA_ID  YYYYMM      Date    Value  Column_Order             Description  \
# 0  WDPRBUS  197301  1/1/1973   129.63             1  Wood Energy Production
# 1  WDPRBUS  197302  2/1/1973  117.194             1  Wood Energy Production
# 2  WDPRBUS  197303  3/1/1973  129.763             1  Wood Energy Production
# 3  WDPRBUS  197304  4/1/1973  125.462             1  Wood Energy Production
# 4  WDPRBUS  197305  5/1/1973  129.624             1  Wood Energy Production
#
#            Unit
# 0  Trillion Btu
# 1  Trillion Btu
# 2  Trillion Btu
# 3  Trillion Btu
# 4  Trillion Btu

# %%
energy_production["Description"].unique()
# Out:
# array(['Wood Energy Production', 'Biofuels Production',
#        'Total Biomass Energy Production',
#        'Total Renewable Energy Production', 'Coal Production',
#        'Natural Gas (Dry) Production', 'Crude Oil Production',
#        'Natural Gas Plant Liquids Production',
#        'Total Fossil Fuels Production',
#        'Nuclear Electric Power Production',
#        'Hydroelectric Power Production', 'Geothermal Energy Production',
#        'Solar Energy Production', 'Wind Energy Production',
#        'Biomass Energy Production', 'Total Primary Energy Production'],
#       dtype=object)

# %% [markdown]
# ### **Energy Data - Stocks.csv**

# %%
# import data

energy_stocks_path = data_folderpath + r"\Energy Data - Stocks.csv"
energy_stocks = pd.read_csv(energy_stocks_path)

energy_stocks.head()
# Out:
#     EIA_ID  YYYYMM      Date           Value  Column_Order  \
# 0  COSQPUS  197301  1/1/1973  Not Applicable             1
# 1  COSQPUS  197302  2/1/1973  Not Applicable             1
# 2  COSQPUS  197303  3/1/1973  Not Applicable             1
# 3  COSQPUS  197304  4/1/1973  Not Applicable             1
# 4  COSQPUS  197305  5/1/1973  Not Applicable             1
#
#              Description             Unit      Energy Type Energy Category  \
# 0  Crude Oil Stocks, SPR  Million Barrels  Crude Oil - SPR       Crude Oil
# 1  Crude Oil Stocks, SPR  Million Barrels  Crude Oil - SPR       Crude Oil
# 2  Crude Oil Stocks, SPR  Million Barrels  Crude Oil - SPR       Crude Oil
# 3  Crude Oil Stocks, SPR  Million Barrels  Crude Oil - SPR       Crude Oil
# 4  Crude Oil Stocks, SPR  Million Barrels  Crude Oil - SPR       Crude Oil
#
#   Energy Class Sector
# 0    Petroleum    NaN
# 1    Petroleum    NaN
# 2    Petroleum    NaN
# 3    Petroleum    NaN
# 4    Petroleum    NaN

# %% [markdown]
# ## Monthly Transportation Statistics
#
# **monthly_transportation_statistics.csv**

# %%
# import data

monthly_transportation_path = data_folderpath + r"\monthly_transportation_statistics.csv"
monthly_transportation = pd.read_csv(monthly_transportation_path)

monthly_transportation.head()
# Out:
#                      Date  Month  Year  \
# 0  01/01/2000 12:00:00 AM      1  2000
# 1  02/01/2000 12:00:00 AM      2  2000
# 2  03/01/2000 12:00:00 AM      3  2000
# 3  04/01/2000 12:00:00 AM      4  2000
# 4  05/01/2000 12:00:00 AM      5  2000
#
#    Air Safety - General Aviation Fatalities  \
# 0                                     119.0
# 1                                      48.0
# 2                                      38.0
# 3                                      62.0
# 4                                      86.0
#
#    Highway Fatalities Per 100 Million Vehicle Miles Traveled  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Highway Fatalities  U.S. Airline Traffic - Total - Seasonally Adjusted  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
#
#    U.S. Airline Traffic - International - Seasonally Adjusted  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    U.S. Airline Traffic - Domestic - Seasonally Adjusted  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Transit Ridership - Other Transit Modes - Adjusted  ...  \
# 0                                                NaN   ...
# 1                                                NaN   ...
# 2                                                NaN   ...
# 3                                                NaN   ...
# 4                                                NaN   ...
#
#    Heavy truck sales SAAR (millions)  \
# 0                           521000.0
# 1                           522000.0
# 2                           521000.0
# 3                           497000.0
# 4                           476000.0
#
#    U.S. Airline Traffic - Total - Non Seasonally Adjusted  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Light truck sales SAAR (millions)  \
# 0                          8808000.0
# 1                          9313000.0
# 2                          8851000.0
# 3                          8539000.0
# 4                          8590000.0
#
#    U.S. Airline Traffic - International - Non Seasonally Adjusted  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Auto sales SAAR (millions)  \
# 0                   9307000.0
# 1                   9566000.0
# 2                   8970000.0
# 3                   8903000.0
# 4                   8877000.0
#
#    U.S. Airline Traffic - Domestic - Non Seasonally Adjusted  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Transborder - Total North American Freight  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Transborder - U.S. - Mexico Freight  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    U.S. marketing air carriers on-time performance (percent)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Transborder - U.S. - Canada Freight
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 137 columns]
